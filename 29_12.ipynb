# %%
# %sql
select 1

# %%
print ("databricks")

# %%
# %sql
create or replace table demo_table (
    id int,
    name string
)

# %%
# %sql
select * from demo_table

# %%
# %sql
insert into demo_table
values (1, 'vrund'), (2, 'virat')

# %%
# %sql
describe detail demo_table

# %%
# %sql
describe extended demo_table
